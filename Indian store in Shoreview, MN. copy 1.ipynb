# %% [markdown]
# ###### Introduction/Business Problem.

# %% [markdown]
# #### I have lived in Shoreview, MN for a long time. And being of Indian origin, one perpetual issue was to have to drive about 30-45 minutes each time we had to buy our local Indian groceries which included the famous spices, sweet or spicy snacks and vegetables. I could like to identify the location for an Indian grocery store which is close by to Shoreview, MN.

# %% [markdown]
# #### Target Audience.

# %% [markdown]
# #### There is a burgeoning population of Indian origian in this area. This population is comprised of engineers and doctors who are of a high income group. Considering the increasing Indian population, there is veritably a need for an Indian grocery store. Indians by nature like to cook at home and are addicted to snacks both sweet or spicy from their home country. And this section of the population has the resources, the knowledge  and need for high quality organic Indian groceries Considering many of this population are doctors, they care for health food without preservatives. So, an Indian grocery store in this area is very much needed.

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geopy-1.21.0               |             py_0          58 KB  conda-forge
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     openssl-1.1.1d             |       h516909a_0         2.1 MB  conda-forge
#     certifi-2019.11.28         |           py36_0         149 KB  conda-forge
#     ca-certificates-2019.11.28 |       hecc5488_0         145 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.5 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib:   1.50-py_0         conda-forge
#     geopy:           1.21.0-py_0       conda-forge
#
# ...

# %%
CLIENT_ID = '0GDBP24PLBVTNHRDEVBRVPWQE5TYCUMZHKR2ZFGAFJARRD3Y' # your Foursquare ID
CLIENT_SECRET = 'T1B5B1JJAUIZDJUL3CYNQZZ2KGXJCKCCY1DDUYBT5R2BB0WR' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 0GDBP24PLBVTNHRDEVBRVPWQE5TYCUMZHKR2ZFGAFJARRD3Y
# CLIENT_SECRET:T1B5B1JJAUIZDJUL3CYNQZZ2KGXJCKCCY1DDUYBT5R2BB0WR

# %%
address = 'Shoreview, MN'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 45.0722056 -93.1282878

# %% [markdown]
# ###### I ran the query with a radius of 500 metres of the longitude and latitude of Shoreview, MN.

# %%
search_query = 'Indian'
LIMIT = 100
radius = 500
print(search_query + ' .... OK!')
# Out:
# Indian .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=0GDBP24PLBVTNHRDEVBRVPWQE5TYCUMZHKR2ZFGAFJARRD3Y&client_secret=T1B5B1JJAUIZDJUL3CYNQZZ2KGXJCKCCY1DDUYBT5R2BB0WR&ll=45.0722056,-93.1282878&v=20180605&query=Indian&radius=30000&limit=100'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e49ea9f923935001b8c49a6'},
#  'response': {'venues': [{'id': '49fc7b39f964a520aa6e1fe3',
#     'name': 'Indian Mounds Park',
#     'location': {'address': '10 Mounds Blvd.',
#      'lat': 44.946439732512395,
#      'lng': -93.05668830871582,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.946439732512395,
#        'lng': -93.05668830871582}],
#      'distance': 15091,
#      'postalCode': '55106',
#      'cc': 'US',
#      'city': 'Saint Paul',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['10 Mounds Blvd.',
#       'Saint Paul, MN 55106',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'shortName': 'Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1581902578',
# ...

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories delivery.id  \
# 0  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...         NaN
# 1  [{'id': '59d79d6b2e268052fa2a3332', 'name': 'M...         NaN
# 2  [{'id': '4bf58dd8d48988d177941735', 'name': 'D...         NaN
# 3  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...         NaN
# 4  [{'id': '50328a8e91d4c4b30a586d6c', 'name': 'N...         NaN
#
#   delivery.provider.icon.name delivery.provider.icon.prefix  \
# 0                         NaN                           NaN
# 1                         NaN                           NaN
# 2                         NaN                           NaN
# 3                         NaN                           NaN
# 4                         NaN                           NaN
#
#   delivery.provider.icon.sizes delivery.provider.name delivery.url  hasPerk  \
# 0                          NaN                    NaN          NaN    False
# ...

# %% [markdown]
# ###### As you can see, the query results are empty. I had to run the query with a radius of 30,000 metres to get results for the keyword 'Indian'. And it too only pulls up a few Indian restaurants, no stores.

# %%
search_query = 'Indian'
radius = 30000
print(search_query + ' .... OK!')
# Out:
# Indian .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=0GDBP24PLBVTNHRDEVBRVPWQE5TYCUMZHKR2ZFGAFJARRD3Y&client_secret=T1B5B1JJAUIZDJUL3CYNQZZ2KGXJCKCCY1DDUYBT5R2BB0WR&ll=45.0722056,-93.1282878&v=20180605&query=Indian&radius=30000&limit=100'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e49eb339fcb92001ba228be'},
#  'response': {'venues': [{'id': '49fc7b39f964a520aa6e1fe3',
#     'name': 'Indian Mounds Park',
#     'location': {'address': '10 Mounds Blvd.',
#      'lat': 44.946439732512395,
#      'lng': -93.05668830871582,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.946439732512395,
#        'lng': -93.05668830871582}],
#      'distance': 15091,
#      'postalCode': '55106',
#      'cc': 'US',
#      'city': 'Saint Paul',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['10 Mounds Blvd.',
#       'Saint Paul, MN 55106',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'shortName': 'Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1581902619',
# ...

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories delivery.id  \
# 0  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...         NaN
# 1  [{'id': '59d79d6b2e268052fa2a3332', 'name': 'M...         NaN
# 2  [{'id': '4bf58dd8d48988d177941735', 'name': 'D...         NaN
# 3  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...         NaN
# 4  [{'id': '50328a8e91d4c4b30a586d6c', 'name': 'N...         NaN
#
#   delivery.provider.icon.name delivery.provider.icon.prefix  \
# 0                         NaN                           NaN
# 1                         NaN                           NaN
# 2                         NaN                           NaN
# 3                         NaN                           NaN
# 4                         NaN                           NaN
#
#   delivery.provider.icon.sizes delivery.provider.name delivery.url  hasPerk  \
# 0                          NaN                    NaN          NaN    False
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                                  name           categories  \
# 0                                  Indian Mounds Park                 Park
# 1                                  Indian Motorcycles     Motorsports Shop
# 2                         Indian Health Board of Mpls      Doctor's Office
# 3                                    Hot Indian Foods    Indian Restaurant
# 4                       Indian Land Tenure Foundation           Non-Profit
# 5                                   Indian Hills Park                 Park
# 6                            Indian Garden Restaurant    Indian Restaurant
# 7                                    Hot Indian Foods           Food Truck
# 8   Takoda Institute ( A Division of American Indi...         Trade School
# 9                              American Indian Center          Art Gallery
# 10                                     Indian Kitchen    Indian Restaurant
# ...

# %% [markdown]
# ### Plotting these on a map in blue  with Shoreview in red, shows the distance.

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) 

folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Shoreview',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

for lat, lng in zip(dataframe_filtered.lat, dataframe_filtered.lng):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
